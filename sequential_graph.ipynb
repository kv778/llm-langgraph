# %%
from typing import TypedDict
from langgraph.graph import StateGraph
# Out:
# /Users/kartikvishnoi/.pyenv/versions/rag_pipeline/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
class AgentState(TypedDict):
    name: str
    age: str
    final: str

# %%
def first_node(state: AgentState) -> AgentState:
    """First node"""
    print(state)
    state['final'] = f'Hello {state["name"]}! '
    print(f'Updated State: {state}')
    return state

def second_node(state: AgentState) -> AgentState:
    """Second node"""
    print(state)
    state['final'] = state['final'] + f"You are {state['age']} years old."
    print(f'Updated State: {state}')
    return state

# %%
graph = StateGraph(AgentState)
graph.add_node("first", first_node)
graph.add_node("second", second_node)

graph.set_entry_point("first")
graph.add_edge("first","second")
graph.set_finish_point("second")
app = graph.compile()

# %%
res = app.invoke({'name': 'kv',
                  'age': '25'})
# Out:
# {'name': 'kv', 'age': '25'}
# Updated State: {'name': 'kv', 'age': '25', 'final': 'Hello kv! '}
# {'name': 'kv', 'age': '25', 'final': 'Hello kv! '}
# Updated State: {'name': 'kv', 'age': '25', 'final': 'Hello kv! You are 25 years old.'}
